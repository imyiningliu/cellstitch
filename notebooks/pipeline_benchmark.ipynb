# %%
import h5py
import numpy as np
import imageio
from cellpose import models
from cellstitch.pipeline import *
from cellstitch.evaluation import *
from cellstitch.utils import *
import pandas as pd

# %% [markdown]
# # Pipeline Benchmark
#
# Comparision between cellstitch (2D), 3Dcellpose (2.5D), plantseg (3D); using the same training set.
# ### PlantSeg
# - First, created a plantseg virtual enviroment:
# `conda create -n plant-seg -c pytorch -c conda-forge -c lcerrone -c awolny pytorch=1.9 pytorch-3dunet=1.3.7 plantseg`
# - activate the environment: `conda activate plant-seg`
# - download the ovules test dataset: https://osf.io/uzq3w/ to `../data/ovules/plantseg_test/`
# - set the `path` in `plantseg.yaml` to `../data/ovules/plantseg_test/`
# - perform segmentation with the `confocal_unet_bce_dice_ds1x` by running `plantseg --config plantseg.yaml`
# - the predictions are saved to `../data/ovules/plantseg_test/PreProcessing/confocal_unet_bce_dice_ds1x/
# `

# %%
test_filenames = ["N_294_final_crop_ds2", 
                 "N_435_final_crop_ds2",
                 "N_441_final_crop_ds2",
                 "N_511_final_crop_ds2",
                 "N_522_final_crop_ds2",
                 "N_590_final_crop_ds2",
                 "N_593_final_crop_ds2"]

# %%
plantseg_results_folder = "../data/ovules/plantseg_test/PreProcessing/confocal_unet_bce_dice_ds1x/MultiCut/"

# %%
for test_filename in test_filenames: 
    print("Starting %s" % test_filename) 
    
    with h5py.File("%s/%s_predictions_multicut.h5" % (plantseg_results_folder, test_filename), "r") as f:
        plantseg = np.array(list(f['segmentation'])) 
        
    plantseg[np.where(plantseg == 1)] = 0 # plantseg use 1 as labels
    np.save("./results/ovules/pipeline/plantseg/%s.npy" % test_filename, plantseg)

# %% [markdown]
# ### Train cellpose model from scratch
# First, need to prepare training data for cellpose.

# %%
train_filenames = ["N_404_ds2x.npy", 
                  "N_405_A_ds2x.npy", 
                  "N_405_B_ds2x.npy", 
                  "N_416_ds2x.npy",
                  "N_422_ds2x.npy",
                  "N_425_ds2x.npy",
                  "N_428_ds2x.npy",
                  "N_440_ds2x.npy",
                  "N_445_ds2x.npy",
                  "N_449_ds2x.npy",
                  "N_450_ds2x.npy", 
                  "N_451_ds2x.npy",
                  "N_454_ds2x.npy",
                  "N_457_ds2x.npy",
                  "N_458_ds2x.npy",
                  "N_487_ds2x.npy",
                  "N_509_ds2x.npy",
                  "N_512_ds2x.npy",
                   "N_517_ds2x.npy",
                  "N_534_ds2x.npy",
                  "N_535_ds2x.npy",
                  "N_536_ds2x.npy"]

ovules_folder = "../data/ovules"
cellpose_folder = "../data/ovules/cellpose_train"

# %%
for train_filename in train_filenames: 
    img = np.load("%s/raw/%s" % (ovules_folder, train_filename))
    labels = np.load("%s/labels/%s" % (ovules_folder, train_filename)) 
    depth = img.shape[0] 
    
    for i in range(depth): 
        imageio.imwrite("%s/%s_%s.tif" % (cellpose_folder, train_filename, i), img[i])
        imageio.imwrite("%s/%s_%s_masks.tif" % (cellpose_folder, train_filename, i), labels[i])

# %% [markdown]
# `python -m cellpose --train --dir ../data/ovules/cellpose_train --pretrained_model None --n_epochs 100  --verbose`

# %% [markdown]
# ### Generate cellpose3d results

# %%
model_dir = '../data/ovules/cellpose_train/models/cellpose_residual_on_style_on_concatenation_off_cellpose_train_2022_09_19_14_23_42.578556'

# %%
ovules_folder = "../data/ovules"

# %%
flow_threshold = 1
model = models.CellposeModel(gpu=True, pretrained_model=model_dir)

# %%
for test_filename in test_filenames: 
    print("Starting %s" % test_filename)
    img = np.load("%s/raw/%s.npy" % (ovules_folder, test_filename)) 
    masks, _, _ = model.eval(img, do_3D=True, flow_threshold=flow_threshold, channels = [0,0]) 
    np.save("./results/ovules/pipeline/cellpose3d/%s.npy" % test_filename, masks)

# %% [markdown]
# ### Generate cellstitch results

# %%
for test_filename in test_filenames: 
    print("Starting %s" % test_filename)
    img = np.load("%s/raw/%s.npy" % (ovules_folder, test_filename)) 
    
    masks, _, _ = model.eval(list(img), flow_threshold=flow_threshold, channels = [0,0]) 
    cellstitch = np.array(masks)
    full_stitch(cellstitch) 
    np.save("./results/ovules/pipeline/cellstitch/%s.npy" % test_filename, cellstitch)

# %% [markdown]
# # Ovules with High Anistropy

# %% [markdown]
# ### PlantSeg
# - activate the environment: `conda activate plant-seg`
# - make sure to set the `path` in plantseg.yaml to `../data/ovules_subsampled/plantseg_test/`
# - perform segmentation with the `confocal_unet_bce_dice_ds1x` by running `plantseg --config plantseg.yaml`

# %%
plantseg_results_folder = "../data/ovules_subsampled/plantseg_test/PreProcessing/confocal_unet_bce_dice_ds1x/MultiCut/"

# %%
for test_filename in test_filenames: 
    print("Starting %s" % test_filename) 
    
    with h5py.File("%s/%s_predictions_multicut.h5" % (plantseg_results_folder, test_filename), "r") as f:
        plantseg = np.array(list(f['segmentation'])) 
        
    plantseg[np.where(plantseg == 1)] = 0 # plantseg use 1 as labels
    np.save("./results/ovules_subsampled/pipeline/plantseg/%s.npy" % test_filename, plantseg)

# %% [markdown]
# ### Generate cellpose3d results

# %%
model_dir = '../data/ovules/cellpose_train/models/cellpose_residual_on_style_on_concatenation_off_cellpose_train_2022_09_19_14_23_42.578556'

# %%
subsampled_ovules_folder = "../data/ovules_subsampled/"

# %%
flow_threshold = 1
model = models.CellposeModel(gpu=True, pretrained_model=model_dir)

# %%
for test_filename in test_filenames: 
    print("Starting %s" % test_filename)
    img = np.load("%s/raw/%s.npy" % (subsampled_ovules_folder, test_filename)) 
    masks, _, _ = model.eval(img, do_3D=True, flow_threshold=flow_threshold, channels = [0,0]) 
    np.save("./results/ovules_subsampled/pipeline/cellpose3d/%s.npy" % test_filename, masks)

# %% [markdown]
# ### Generate cellstitch results

# %%
for test_filename in test_filenames: 
    print("Starting %s" % test_filename)
    img = np.load("%s/raw/%s.npy" % (subsampled_ovules_folder, test_filename)) 
    
    masks, _, _ = model.eval(list(img), flow_threshold=flow_threshold, channels = [0,0]) 
    cellstitch = np.array(masks)
    full_stitch(cellstitch) 
    np.save("./results/ovules_subsampled/pipeline/cellstitch/%s.npy" % test_filename, cellstitch)

# %% [markdown]
# # Benchmark Results

# %%
dataset = 'ovules_subsampled' # ovules or ovules_subsampled

ap_threshold = 0.5

# %%
# plantseg benchmark
data = [] 
for filename in test_filenames:
    print("Starting %s" % filename)
    labels = np.load('../data/%s/labels/%s.npy' % (dataset, filename)) 
    true_num_cells = np.unique(labels).size - 1 
    true_avg_vol = get_avg_vol(labels) 
    
    masks = np.load("./results/%s/pipeline/plantseg/%s.npy" % (dataset, filename)) 
    
    num_cells = np.unique(masks).size - 1
    d_num_cells = abs(num_cells - true_num_cells) / true_num_cells

    avg_vol = get_avg_vol(masks)
    d_avg_vol = abs(true_avg_vol - avg_vol) / true_avg_vol

    ap, tp, fp, fn = average_precision(labels, masks, ap_threshold)
    
    row = [ 
        filename, 
        d_num_cells, 
        d_avg_vol, 
        ap, 
        tp, 
        fp, 
        fn
    ]
    
    data.append(row)

plantseg_df = pd.DataFrame(data, columns=[
    "filename",  
    "d_num_cells", 
    "d_avg_vol", 
    "ap", 
    "tp", 
    "fp", 
    "fn"
])
plantseg_df.to_csv("./results/%s/pipeline/plantseg.csv" % dataset, index=False)
# Out:
# Starting N_294_final_crop_ds2
# /home/yining/anaconda3/envs/segmentation/lib/python3.8/site-packages/cellpose/metrics.py:205: RuntimeWarning: invalid value encountered in true_divide
#   iou = overlap / (n_pixels_pred + n_pixels_true - overlap)
# Starting N_435_final_crop_ds2
# Starting N_441_final_crop_ds2
# Starting N_511_final_crop_ds2
# Starting N_522_final_crop_ds2
# Starting N_590_final_crop_ds2
# Starting N_593_final_crop_ds2

# %%
# cellpose3d benchmark
data = [] 
for filename in test_filenames:
    print("Starting %s" % filename)
    labels = np.load('../data/%s/labels/%s.npy' % (dataset, filename))
    true_num_cells = np.unique(labels).size - 1 
    true_avg_vol = get_avg_vol(labels) 
    
    masks = np.load("./results/%s/pipeline/cellpose3d/%s.npy" % (dataset, filename)) 
    
    num_cells = np.unique(masks).size - 1
    d_num_cells = abs(num_cells - true_num_cells) / true_num_cells

    avg_vol = get_avg_vol(masks)
    d_avg_vol = abs(true_avg_vol - avg_vol) / true_avg_vol

    ap, tp, fp, fn = average_precision(labels, masks, ap_threshold)
    
    row = [ 
        filename, 
        d_num_cells, 
        d_avg_vol, 
        ap, 
        tp, 
        fp, 
        fn
    ]
    
    data.append(row)

cp_df = pd.DataFrame(data, columns=[
    "filename",  
    "d_num_cells", 
    "d_avg_vol", 
    "ap", 
    "tp", 
    "fp", 
    "fn"
])

cp_df.to_csv("./results/%s/pipeline/cellpose3d.csv" % dataset, index=False)
# Out:
# Starting N_294_final_crop_ds2
# Starting N_435_final_crop_ds2
# Starting N_441_final_crop_ds2
# Starting N_511_final_crop_ds2
# Starting N_522_final_crop_ds2
# Starting N_590_final_crop_ds2
# Starting N_593_final_crop_ds2

# %%
# cellstitch benchmark
data = [] 
for filename in test_filenames:
    print("Starting %s" % filename)
    labels = np.load('../data/%s/labels/%s.npy' % (dataset, filename)) 
    true_num_cells = np.unique(labels).size - 1 
    true_avg_vol = get_avg_vol(labels) 
    
    masks = np.load("./results/%s/pipeline/cellstitch/%s.npy" % (dataset, filename))
    
    num_cells = np.unique(masks).size - 1
    d_num_cells = abs(num_cells - true_num_cells) / true_num_cells

    avg_vol = get_avg_vol(masks)
    d_avg_vol = abs(true_avg_vol - avg_vol) / true_avg_vol

    ap, tp, fp, fn = average_precision(labels, masks, ap_threshold)
    
    row = [ 
        filename, 
        d_num_cells, 
        d_avg_vol, 
        ap, 
        tp, 
        fp, 
        fn
    ]
    
    data.append(row)

ct_df = pd.DataFrame(data, columns=[
    "filename",  
    "d_num_cells", 
    "d_avg_vol", 
    "ap", 
    "tp", 
    "fp", 
    "fn"
])

ct_df.to_csv("./results/%s/pipeline/cellstitch.csv" % dataset, index=False)
# Out:
# Starting N_294_final_crop_ds2
# /home/yining/anaconda3/envs/segmentation/lib/python3.8/site-packages/cellpose/metrics.py:205: RuntimeWarning: invalid value encountered in true_divide
#   iou = overlap / (n_pixels_pred + n_pixels_true - overlap)
# Starting N_435_final_crop_ds2
# Starting N_441_final_crop_ds2
# Starting N_511_final_crop_ds2
# Starting N_522_final_crop_ds2
# Starting N_590_final_crop_ds2
# Starting N_593_final_crop_ds2

# %% [markdown]
# ### Analyze Results

# %%
df = pd.read_csv('results/ovules_subsampled/pipeline/plantseg.csv')

# %%
df.mean()
# Out:
# /tmp/ipykernel_387550/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# d_num_cells       0.686598
# d_avg_vol         1.063578
# ap                0.115152
# tp              454.857143
# fp             2129.142857
# fn             1255.714286
# dtype: float64

# %%
df.std()
# Out:
# /tmp/ipykernel_387550/3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# d_num_cells      0.492997
# d_avg_vol        0.535862
# ap               0.035435
# tp             309.580053
# fp             926.301504
# fn             727.763632
# dtype: float64

# %% [markdown]
# # ATAS benchmark

# %%
anisotropies = [0, 2, 4, 6, 8, 10]

flow_threshold = 1
model = models.Cellpose(gpu=True, model_type='cyto2')

# %% [markdown]
# ## Generate cellpose3d results

# %%
for anisotropy in anisotropies: 
    print("=== Starting anisotropy %s ===" % anisotropy)
    filenames = get_filenames("../DATA/ATAS_%s/raw" % anisotropy)
    
    dataset_folder = "../DATA/ATAS_%s" % anisotropy
    for filename in filenames: 
        print("Starting %s" % filename)
        img = np.load("%s/raw/%s" % (dataset_folder, filename)) 
        masks, _, _, _ = model.eval(img, do_3D=True, flow_threshold=flow_threshold) 
        np.save("./results/ATAS/pipeline/a%s/cellpose3d/%s" % (anisotropy, filename), masks)
# Out:
# === Starting anisotropy 2 ===
# Starting 16hrs_plant4_trim-acylYFP.npy
# Starting 60hrs_plant18_trim-acylYFP.npy
# Starting 36hrs_plant15_trim-acylYFP.npy
# Starting 52hrs_plant4_trim-acylYFP.npy
# Starting 64hrs_plant1_trim-acylYFP.npy
# Starting 32hrs_plant1_trim-acylYFP.npy
# Starting 36hrs_plant2_trim-acylYFP.npy
# Starting 44hrs_plant1_trim-acylYFP.npy
# Starting 68hrs_plant15_trim-acylYFP.npy
# Starting 84hrs_plant18_trim-acylYFP.npy
# Starting 64hrs_plant18_trim-acylYFP.npy
# Starting 28hrs_plant2_trim-acylYFP.npy
# Starting 12hrs_plant4_trim-acylYFP.npy
# Starting 32hrs_plant2_trim-acylYFP.npy
# Starting 80hrs_plant18_trim-acylYFP.npy
# Starting 48hrs_plant1_trim-acylYFP.npy
# Starting 0hrs_plant4_trim-acylYFP.npy
# Starting 36hrs_plant18_trim-acylYFP.npy
# Starting 28hrs_plant13_trim-acylYFP.npy
# Starting 8hrs_plant13_trim-acylYFP.npy
# Starting 72hrs_plant18_trim-acylYFP.npy
# Starting 24hrs_plant13_trim-acylYFP.npy
# Starting 0hrs_plant18_trim-acylYFP.npy
# Starting 48hrs_plant4_trim-acylYFP.npy
# Starting 76hrs_plant15_trim-acylYFP.npy
# Starting 52hrs_plant15_trim-acylYFP.npy
# === Starting anisotropy 10 ===
# Starting 16hrs_plant4_trim-acylYFP.npy
# Starting 60hrs_plant18_trim-acylYFP.npy
# Starting 36hrs_plant15_trim-acylYFP.npy
# Starting 52hrs_plant4_trim-acylYFP.npy
# Starting 64hrs_plant1_trim-acylYFP.npy
# Starting 32hrs_plant1_trim-acylYFP.npy
# Starting 36hrs_plant2_trim-acylYFP.npy
# Starting 44hrs_plant1_trim-acylYFP.npy
# Starting 68hrs_plant15_trim-acylYFP.npy
# Starting 84hrs_plant18_trim-acylYFP.npy
# Starting 64hrs_plant18_trim-acylYFP.npy
# Starting 56hrs_plant18_trim-acylYFP.npy
# Starting 72hrs_plant2_trim-acylYFP.npy
# Starting 60hrs_plant13_trim-acylYFP.npy
# Starting 24hrs_plant1_trim-acylYFP.npy
# Starting 60hrs_plant4_trim-acylYFP.npy
# Starting 24hrs_plant15_trim-acylYFP.npy
# Starting 16hrs_plant15_trim-acylYFP.npy
# Starting 12hrs_plant18_trim-acylYFP.npy
# Starting 20hrs_plant4_trim-acylYFP.npy
# Starting 72hrs_plant1_trim-acylYFP.npy
# Starting 80hrs_plant13_trim-acylYFP.npy
# Starting 4hrs_plant2_trim-acylYFP.npy
# Starting 84hrs_plant13_trim-acylYFP_improved.npy
# Starting 36hrs_plant1_trim-acylYFP.npy
# Starting 16hrs_plant18_trim-acylYFP.npy
# Starting 16hrs_plant13_trim-acylYFP.npy
# Starting 48hrs_plant13_trim-acylYFP.npy
# Starting 24hrs_plant18_trim-acylYFP.npy
# Starting 0hrs_plant15_trim-acylYFP.npy
# Starting 56hrs_plant13_trim-acylYFP.npy
# Starting 40hrs_plant13_trim-acylYFP.npy
# Starting 20hrs_plant15_trim-acylYFP.npy
# Starting 24hrs_plant2_trim-acylYFP.npy
# Starting 40hrs_plant15_trim-acylYFP.npy
# Starting 68hrs_plant18_trim-acylYFP.npy
# Starting 48hrs_plant18_trim-acylYFP.npy
# Starting 4hrs_plant4_trim-acylYFP.npy
# Starting 24hrs_plant4_trim-acylYFP.npy
# Starting 20hrs_plant18_trim-acylYFP.npy
# Starting 76hrs_plant1_trim-acylYFP.npy
# Starting 64hrs_plant2_trim-acylYFP.npy
# Starting 28hrs_plant18_trim-acylYFP.npy
# Starting 40hrs_plant1_trim-acylYFP.npy
# Starting 76hrs_plant13_trim-acylYFP.npy
# Starting 48hrs_plant15_trim-acylYFP.npy
# Starting 44hrs_plant15_trim-acylYFP.npy
# Starting 8hrs_plant15_trim-acylYFP.npy
# Starting 32hrs_plant15_trim-acylYFP.npy
# Starting 12hrs_plant13_trim-acylYFP.npy
# Starting 52hrs_plant13_trim-acylYFP.npy
# Starting 8hrs_plant2_trim-acylYFP.npy
# Starting 80hrs_plant15_trim-acylYFP.npy
# Starting 68hrs_plant4_trim-acylYFP.npy
# Starting 52hrs_plant18_trim-acylYFP.npy
# Starting 52hrs_plant1_trim-acylYFP.npy
# Starting 72hrs_plant15_trim-acylYFP.npy
# Starting 0hrs_plant1_trim-acylYFP.npy
# Starting 8hrs_plant4_trim-acylYFP.npy
# Starting 48hrs_plant2_trim-acylYFP.npy
# Starting 52hrs_plant2_trim-acylYFP.npy
# Starting 56hrs_plant1_trim-acylYFP.npy
# Starting 60hrs_plant2_trim-acylYFP.npy
# Starting 0hrs_plant2_trim-acylYFP.npy
# Starting 20hrs_plant13_trim-acylYFP.npy
# Starting 0hrs_plant13_trim-acylYFP.npy
# Starting 4hrs_plant15_trim-acylYFP.npy
# Starting 8hrs_plant18_trim-acylYFP.npy
# Starting 68hrs_plant2_trim-acylYFP.npy
# Starting 16hrs_plant1_trim-acylYFP.npy
# Starting 84hrs_plant15_trim-acylYFP.npy
# Starting 72hrs_plant13_trim-acylYFP.npy
# Starting 32hrs_plant4_trim-acylYFP.npy
# Starting 68hrs_plant1_trim-acylYFP.npy
# Starting 68hrs_plant13_trim-acylYFP.npy
# Starting 60hrs_plant1_trim-acylYFP.npy
# Starting 64hrs_plant13_trim-acylYFP.npy
# Starting 44hrs_plant2_trim-acylYFP.npy
# Starting 76hrs_plant2_trim-acylYFP.npy
# Starting 4hrs_plant18_trim-acylYFP.npy
# Starting 12hrs_plant1_trim-acylYFP.npy
# Starting 32hrs_plant18_trim-acylYFP.npy
# Starting 56hrs_plant2_trim-acylYFP.npy
# Starting 12hrs_plant2_trim-acylYFP.npy
# Starting 20hrs_plant1_trim-acylYFP.npy
# Starting 32hrs_plant13_trim-acylYFP.npy
# Starting 28hrs_plant1_trim-acylYFP.npy
# Starting 44hrs_plant18_trim-acylYFP.npy
# Starting 40hrs_plant4_trim-acylYFP.npy
# Starting 20hrs_plant2_trim-acylYFP.npy
# Starting 28hrs_plant15_trim-acylYFP.npy
# Starting 56hrs_plant15_trim-acylYFP.npy
# Starting 28hrs_plant4_trim-acylYFP.npy
# Starting 4hrs_plant13_trim-acylYFP.npy
# Starting 56hrs_plant4_trim-acylYFP.npy
# Starting 40hrs_plant2_trim-acylYFP.npy
# Starting 72hrs_plant4_trim-acylYFP.npy
# Starting 44hrs_plant13_trim-acylYFP.npy
# Starting 36hrs_plant4_trim-acylYFP.npy
# Starting 12hrs_plant15_trim-acylYFP.npy
# Starting 36hrs_plant13_trim-acylYFP.npy
# Starting 64hrs_plant15_trim-acylYFP.npy
# Starting 76hrs_plant4_trim-acylYFP.npy
# Starting 16hrs_plant2_trim-acylYFP.npy
# Starting 8hrs_plant1_trim-acylYFP.npy
# Starting 60hrs_plant15_trim-acylYFP.npy
# Starting 4hrs_plant1_trim-acylYFP.npy
# Starting 44hrs_plant4_trim-acylYFP.npy
# Starting 76hrs_plant18_trim-acylYFP.npy
# Starting 64hrs_plant4_trim-acylYFP.npy
# Starting 28hrs_plant2_trim-acylYFP.npy
# Starting 12hrs_plant4_trim-acylYFP.npy
# Starting 32hrs_plant2_trim-acylYFP.npy
# Starting 80hrs_plant18_trim-acylYFP.npy
# Starting 48hrs_plant1_trim-acylYFP.npy
# Starting 0hrs_plant4_trim-acylYFP.npy
# Starting 36hrs_plant18_trim-acylYFP.npy
# Starting 28hrs_plant13_trim-acylYFP.npy
# Starting 8hrs_plant13_trim-acylYFP.npy
# Starting 72hrs_plant18_trim-acylYFP.npy
# Starting 24hrs_plant13_trim-acylYFP.npy
# Starting 0hrs_plant18_trim-acylYFP.npy
# Starting 48hrs_plant4_trim-acylYFP.npy
# Starting 76hrs_plant15_trim-acylYFP.npy
# Starting 52hrs_plant15_trim-acylYFP.npy

# %% [markdown]
# ## Generate cellstitch results

# %%
anisotropies = [0, 2, 4, 6, 8, 10]

for anisotropy in anisotropies: 
    print("=== Starting anisotropy %s ===" % anisotropy)
    filenames = get_filenames("../DATA/ATAS_%s/raw" % anisotropy)
    
    dataset_folder = "../DATA/ATAS_%s" % anisotropy
    for filename in filenames: 
        
        print("Starting %s" % filename)
        img = np.load("%s/raw/%s" % (dataset_folder, filename)) 
        masks, _, _, _ = model.eval(list(img), flow_threshold=flow_threshold) 
        cellstitch = np.array(masks)
        full_stitch(cellstitch) 
        np.save("./results/ATAS/pipeline/a%s/cellstitch/%s" % (anisotropy, filename), cellstitch)
# Out:
# === Starting anisotropy 0 ===
# Starting 16hrs_plant4_trim-acylYFP.npy
# Starting 60hrs_plant18_trim-acylYFP.npy
# Starting 36hrs_plant15_trim-acylYFP.npy
# Starting 52hrs_plant4_trim-acylYFP.npy
# Starting 64hrs_plant1_trim-acylYFP.npy
# Starting 32hrs_plant1_trim-acylYFP.npy
# Starting 36hrs_plant2_trim-acylYFP.npy
# Starting 44hrs_plant1_trim-acylYFP.npy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [31], in <module>
#      12 masks, _, _, _ = model.eval(list(img), flow_threshold=flow_threshold)
#      13 cellstitch = np.array(masks)
# ---> 14 full_stitch(cellstitch)
#      15 np.save("./results/ATAS/pipeline/a%s/cellstitch/%s" % (anisotropy, filename), cellstitch)
#
# File ~/cellstitch/cellstitch/pipeline.py:76, in full_stitch(masks, verbose)
#      73         prev_index = curr_index
#      74         curr_index += 1
# ---> 76 overseg_correction(masks)
#
# File ~/cellstitch/cellstitch/pipeline.py:31, in overseg_correction(masks)
#      28 layers_lbls = {}
#      30 for lbl in lbls:
# ---> 31     existing_layers = np.sum(masks == lbl, axis=(1, 2), dtype="bool")
#      32     depth = existing_layers.sum()
#      34     if depth == 1:
#
# KeyboardInterrupt:
